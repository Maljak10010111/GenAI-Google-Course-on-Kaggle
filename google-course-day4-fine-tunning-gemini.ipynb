# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pip install -U -q 'google-generativeai>=0.8.3
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai

# %%
from kaggle_secrets import UserSecretsClient

GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for model in genai.list_models():
    if "createTunedModel" in model.supported_generation_methods:
        print(model.name)
# Out:
# models/gemini-1.0-pro-001
# models/gemini-1.5-flash-001-tuning

# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset="train")
newsgroups_test = fetch_20newsgroups(subset="test")

# View list of class names for dataset
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
import email
import re

import pandas as pd


def preprocess_newsgroup_row(data):
    # Extract only the subject and body
    msg = email.message_from_string(data)
    text = f"{msg['Subject']}\n\n{msg.get_payload()}"
    # Strip any remaining email addresses
    text = re.sub(r"[\w\.-]+@[\w\.-]+", "", text)
    # Truncate the text to fit within the input limits
    text = text[:40000]

    return text


def preprocess_newsgroup_data(newsgroup_dataset):
    # Put data points into dataframe
    df = pd.DataFrame(
        {"Text": newsgroup_dataset.data, "Label": newsgroup_dataset.target}
    )
    # Clean up the text
    df["Text"] = df["Text"].apply(preprocess_newsgroup_row)
    # Match label to target name index
    df["Class Name"] = df["Label"].map(lambda l: newsgroup_dataset.target_names[l])

    return df

# %%
# Apply preprocessing to training and test datasets
df_train = preprocess_newsgroup_data(newsgroups_train)
df_test = preprocess_newsgroup_data(newsgroups_test)

df_train.head()
# Out:
#                                                 Text  Label  \
# 0  WHAT car is this!?\n\n I was wondering if anyo...      7
# 1  SI Clock Poll - Final Call\n\nA fair number of...      4
# 2  PB questions...\n\nwell folks, my mac plus fin...      4
# 3  Re: Weitek P9000 ?\n\nRobert J.C. Kyanko () wr...      1
# 4  Re: Shuttle Launch Question\n\nFrom article <>...     14
#
#               Class Name
# 0              rec.autos
# 1  comp.sys.mac.hardware
# 2  comp.sys.mac.hardware
# 3          comp.graphics
# 4              sci.space

# %% [markdown]
# **Now sample the data.** <br>
# I keep 50 rows for each category for training. This technique (parameter-efficient fine-tuning, or PEFT) updates a relatively small number of parameters and does not require training a new model or updating the large model.

# %%
def sample_data(df, num_samples, classes_to_keep):
    # Sample rows, selecting num_samples of each Label.
    df = (
        df.groupby("Label")[df.columns]
        .apply(lambda x: x.sample(num_samples))
        .reset_index(drop=True)
    )

    df = df[df["Class Name"].str.contains(classes_to_keep)]
    df["Class Name"] = df["Class Name"].astype("category")

    return df


TRAIN_NUM_SAMPLES = 50
TEST_NUM_SAMPLES = 10
# Keep rec.* and sci.*
CLASSES_TO_KEEP = "^rec|^sci"

df_train = sample_data(df_train, TRAIN_NUM_SAMPLES, CLASSES_TO_KEEP)
df_test = sample_data(df_test, TEST_NUM_SAMPLES, CLASSES_TO_KEEP)

# %% [markdown]
# **Evaluating baseline performance** <br>
# Before I start with fine-tuning it is a good practice to mesaure current performance to compare the improvment of fine-tuning later on.

# %%
sample_idx = 0
sample_row = preprocess_newsgroup_row(newsgroups_test.data[sample_idx])
sample_label = newsgroups_test.target_names[newsgroups_test.target[sample_idx]]

print(sample_row)
print('---')
print('Label:', sample_label)
# Out:
# Need info on 88-89 Bonneville
#
#
#  I am a little confused on all of the models of the 88-89 bonnevilles.
# I have heard of the LE SE LSE SSE SSEI. Could someone tell me the
# differences are far as features or performance. I am also curious to
# know what the book value is for prefereably the 89 model. And how much
# less than book value can you usually get them for. In other words how
# much are they in demand this time of year. I have heard that the mid-spring
# early summer is the best time to buy.
#
# 			Neil Gandler
#
# ---
# Label: rec.autos

# %% [markdown]
# Passing the text directly in as a prompt does not yield the desired results. The model will attempt to respond to the message.

# %%
baseline_model = genai.GenerativeModel("gemini-1.5-flash-001")
response = baseline_model.generate_content(sample_row)
print(response.text)
# Out:
# You're right, the 88-89 Bonneville model lineup can be confusing! Here's a breakdown of the differences between the various trim levels:
#
# **1988-1989 Bonneville Trim Levels**
#
# * **Base:** This was the most basic version, offering a 3.8L V6 engine and a fairly standard interior.
# * **LE (Luxury Edition):** This added features like power windows, locks, and mirrors, plusher upholstery, and possibly a slightly upgraded stereo.
# * **SE (Special Edition):** This trim level offered a more sporty look with unique badging, wheels, and sometimes a slightly peppier engine.
# * **LSE (Luxury Special Edition):** This combined the features of the LE and SE, offering a luxury-sport feel.
# * **SSE (Sport Sedan Edition):** This trim level featured the most powerful engine option, the 3.8L V6 with a turbocharger. It also had a more aggressive exterior and interior styling, including sport seats.
# * **SSEi (Sport Sedan Edition, injected):** This was the highest performance model, boasting a turbocharged 3.8L V6 engine with fuel injection, resulting in more horsepower and torque. It had the most aggressive styling and premium features.
#
# **Book Value and Market Demand**
#
# Unfortunately, providing an accurate book value for an 89 Bonneville is impossible without knowing the specific condition, mileage, and overall maintenance history. However, you can get a good estimate by using online resources like:
#
# * **Kelley Blue Book (KBB):** [https://www.kbb.com/](https://www.kbb.com/)
# * **Edmunds:** [https://www.edmunds.com/](https://www.edmunds.com/)
# * **NADA Guides:** [https://www.nadaguides.com/](https://www.nadaguides.com/)
#
# **Pricing and Demand**
#
# The demand for 88-89 Bonnevilles can fluctuate depending on the specific trim level and condition. Generally, these older models are not in high demand, but the SSE and SSEi versions can be more desirable due to their performance.
#
# Here's what you can typically expect:
#
# * **Lower-end models (Base, LE):**  Expect to find these for under $2,000, especially if they have higher mileage or require some work.
# * **Mid-range models (SE, LSE):**  These will likely range from $2,000 to $4,000 depending on condition.
# * **High-performance models (SSE, SSEi):**  These can fetch anywhere from $3,000 to $5,000+ if in good shape.
#
# **Negotiating and Buying**
#
# While mid-spring to early summer can be a good time to buy, you can find good deals year-round. Here are some tips:
#
# * **Do your research:** Know what similar cars are selling for in your area to get an idea of fair pricing.
# * **Be patient:** Don't rush into a purchase; take your time to find the right car.
# * **Negotiate:** Don't be afraid to negotiate on the price, especially if the car has any flaws.
# * **Have a pre-purchase inspection:** This will help you identify any potential problems before you buy.
#
# **Important Considerations:**
#
# * **Parts availability:**  Finding parts for these older models can be a challenge.
# * **Fuel economy:**  These cars weren't known for their fuel efficiency.
# * **Reliability:**  While they can be reliable, some common issues include engine problems, transmission issues, and electrical problems.
#
# Good luck with your search!

# %%
# Ask the model directly in a zero-shot prompt.

prompt = "From what newsgroup does the following message originate?"
baseline_response = baseline_model.generate_content([prompt, sample_row])
print(baseline_response.text)
# Out:
# Based on the content of the message and the use of "book value," it is likely from a newsgroup focused on **Buick automobiles**, specifically **Bonneville models**.
#
# Here's why:
#
# * **Specific model discussion:** The message explicitly mentions different Bonneville trims (LE, SE, LSE, SSE, SSEi) and seeks information about their features and performance.
# * **Book value inquiry:**  The mention of "book value" is a common term used in automotive discussions to refer to a vehicle's estimated worth based on its condition, mileage, and market trends.
# * **Seasonal pricing:**  The mention of "mid-spring early summer" as the best time to buy aligns with typical seasonal fluctuations in car prices.
#
# Therefore, a likely newsgroup origin could be something like:
#
# * **alt.autos.buick**
# * **rec.autos.buick**
# * **rec.autos.cars.buick**
#
# These are typical names for newsgroups dedicated to specific car brands.

# %%
from google.api_core import retry

# MORE DIRECT PROMPTING

system_instruct = """
You are a classification service. You will be passed input that represents
a newsgroup post and you must respond with the newsgroup from which the post
originates.
"""

instructed_model = genai.GenerativeModel("gemini-1.5-flash-001",
                                         system_instruction=system_instruct)

retry_policy = {"retry": retry.Retry(predicate=retry.if_transient_error)}


def predict_label(post: str) -> str:
    response = instructed_model.generate_content(post, request_options=retry_policy)
    rc = response.candidates[0]

    # Any errors, filters, recitation, etc we can mark as a general error
    if rc.finish_reason.name != "STOP":
        return "(error)"
    else:
        # Clean up the response.
        return response.text.strip()


prediction = predict_label(sample_row)

print(prediction)
print()
print("Correct!" if prediction == sample_label else "Incorrect.")
# Out:
# rec.autos.misc
#
# Incorrect.

# %%
# small evaluation
from tqdm.rich import tqdm

tqdm.pandas()


# Further sample the test data to be mindful of the free-tier quota.
df_baseline_eval = sample_data(df_test, 2, '.*')

# Make predictions using the sampled data.
df_baseline_eval['Prediction'] = df_baseline_eval['Text'].progress_apply(predict_label)

# And calculate the accuracy.
accuracy = (df_baseline_eval["Class Name"] == df_baseline_eval["Prediction"]).sum() / len(df_baseline_eval)
print(f"Accuracy: {accuracy:.2%}")
# Out:
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16  [ 0:00:06 < 0:00:00 , 2 it/s ]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accuracy: 31.25%

# %%
# to see predicted_labels vs true_labels
df_baseline_eval
# Out:
#                                                  Text  Label  \
# 0   Re: V4 V6 V8 V12 Vx?\n\nIn article <1r8ufk$>  ...      7
# 1   TRUCKING INDUSTRY\n\n which are them main truc...      7
# 2   Re: RE:windy days\n\nIn article <>  (Alan Dunc...      8
# 3   Re: dogs\n\n--> (charles.a.rogers) writes:\n--...      8
# 4   Re: Jewish Baseball Players?\n\nIn article <>,...      9
# 5   Re: Why is Barry Bonds not batting 4th?\n\nIn ...      9
# 6   Re: ESPN UP YOURS .........\n\nActually, I was...     10
# 7   Re: Maybe next year Hawks\n\nIn article <>,\n ...     10
# 8   Re: REVISED TECHNICAL SUMMARY OF CLIPPER CHIP\...     11
# 9   Re: Clipper chip\n\nIn article <>\n\t (Philipp...     11
# 10  HP 200CD manual\n\nThe 200CD is one of three o...     12
# 11  ___Fax Machine scanners to mono-computer scann...     12
# 12  Re: Umbilical Hernia\n\nIn article <>  (Gary T...     13
# 13  Re: Patti Duke's Problem\n\nIn article <>  wri...     13
# 14  Re: Gamma Ray Bursters.  WHere  are they.\n\nI...     14
# 15  Re: Gamma Ray Bursters. WHere are they.\n\nIn ...     14
#
#             Class Name                Prediction
# 0            rec.autos        rec.autos.imported
# 1            rec.autos                 rec.autos
# 2      rec.motorcycles           rec.motorcycles
# 3      rec.motorcycles           rec.motorcycles
# 4   rec.sport.baseball       rec.sports.baseball
# 5   rec.sport.baseball        rec.sport.baseball
# 6     rec.sport.hockey          rec.sport.hockey
# 7     rec.sport.hockey         rec.sports.hockey
# 8            sci.crypt                   (error)
# 9            sci.crypt                   (error)
# 10     sci.electronics    rec.radio.amateur.misc
# 11     sci.electronics  comp.sys.ibm.pc.hardware
# 12             sci.med             alt.med.herbs
# 13             sci.med        alt.talk.celebrity
# 14           sci.space       comp.astro.research
# 15           sci.space                 sci.astro

# %% [markdown]
# **FINE-TUNING**

# %%
from collections.abc import Iterable
import random


# Append a random number to the model ID so you can re-run with a higher chance
# of creating a unique model ID.
model_id = f"newsgroup-classifier-{random.randint(10000, 99999)}"

# Upload the training data and queue the tuning job.
tuning_op = genai.create_tuned_model(
    "models/gemini-1.5-flash-001-tuning",
    training_data=df_train,
    input_key="Text",  # the column to use as input
    output_key="Class Name",  # the column to use as output
    id=model_id,
    display_name="Newsgroup classification model",
    batch_size=16,
    epoch_count=2,
)

print(model_id)
# Out:
# newsgroup-classifier-28971

# %%
import time
import seaborn as sns


while (tuned_model := genai.get_tuned_model(f"tunedModels/{model_id}")).state.name != 'ACTIVE':

    print(tuned_model.state)
    time.sleep(60)

print(f"Done! The model is {tuned_model.state.name}")

# Plot the loss curve.
snapshots = pd.DataFrame(tuned_model.tuning_task.snapshots)
sns.lineplot(data=snapshots, x="step", y="mean_loss")

# %%
your_model = genai.GenerativeModel(f"tunedModels/{model_id}")

new_text = """
First-timer looking to get out of here.

Hi, I'm writing about my interest in travelling to the outer limits!

What kind of craft can I buy? What is easiest to access from this 3rd rock?

Let me know how to do that please.
"""

response = your_model.generate_content(new_text)
print(response.text)

# %%
def classify_text(text: str) -> str:
    """Classify the provided text into a known newsgroup."""
    response = your_model.generate_content(text, request_options=retry_policy)
    rc = response.candidates[0]

    # Any errors, filters, recitation, etc we can mark as a general error
    if rc.finish_reason.name != "STOP":
        return "(error)"
    else:
        return rc.content.parts[0].text


# The sampling here is just to minimise your quota usage. If you can, you should
# evaluate the whole test set with `df_model_eval = df_test.copy()`.
df_model_eval = sample_data(df_test, 4, '.*')


df_model_eval["Prediction"] = df_model_eval["Text"].progress_apply(classify_text)

accuracy = (df_model_eval["Class Name"] == df_model_eval["Prediction"]).sum() / len(df_model_eval)
print(f"Accuracy: {accuracy:.2%}")

# %%
# Calculate the *input* cost of the baseline model with system instructions.
sysint_tokens = instructed_model.count_tokens(sample_row).total_tokens
print(f'System instructed baseline model: {sysint_tokens} (input)')

# Calculate the input cost of the tuned model.
tuned_tokens = your_model.count_tokens(sample_row).total_tokens
print(f'Tuned model: {tuned_tokens} (input)')

savings = (sysint_tokens - tuned_tokens) / tuned_tokens
print(f'Token savings: {savings:.2%}')  # Note that this is only n=1.

# %%
baseline_token_output = baseline_response.usage_metadata.candidates_token_count
print('Baseline (verbose) output tokens:', baseline_token_output)

tuned_model_output = your_model.generate_content(sample_row)
tuned_tokens_output = tuned_model_output.usage_metadata.candidates_token_count
print('Tuned output tokens:', tuned_tokens_output)
